# %% [markdown]
# # Day 1 - Monday - 4 hours
#
# - Week 1 Retrospective
#
#     - Boot Task
#
# ## Day 2 - Tuesday - 4 hours
#
# - Windows Registry Playbook
#
#     - Export root of registry
#         - binary Value
#         - string Value
#         - DWORD (32-bit) value
#         - QWORD (64-bit) value
#         - Multi-String
#         - Expandable String Value
#
#     - Malware in Registry
#         - HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Windows\CurrentVersion\Run
#         - Insert in Run
#
#     - Registry scripting module
#         - net /?
#         - reg /?
#         - reg query /?
#         - reg query HKLM (query HKLM)
#         - reg query HKLM\System
#         - reg export HKLM c:\users\IEUser\hklm-backup.reg
#         - reg add "HKCU\SOFTWARE\Microsoft\Windows\CurrentVersion\Run" /v "MyMalivcousApp" /t REG_SZ /f /d "C:\MyAppPath\MyApp.exe"
#
#           create MyScript.bat in Documents folder
#           c:\Users\Mary\Documents\MyScript.bat
#
#           - powershell
#             Get-ChildItem -Path Registy::HKCU
#           - Auslogics Registry
#
#             https://www.auslogics.com/en/software/
#
#           - set - display environment variables
#           - echo %userprofile%
#
#           - command
#
#        - applications, processes, services
#            - what are the difference between each?
#            - Different versions of Task Manager prior to Windows 8 and after
#                - Fundamental shift in philosophy in showing process info
#                - have both Windows 7 and Windows 10 images open
#                    - Windows 7
#                        - task manager in control panel
#                        - svchost.exe
#                            - multiple of them
#                            - can inject malware here and we can't even identify if they are real or not
#                            - monitoring health of system in task manager to verify if missing processes are sucking up memories
#                            - memory leak can be threads
#                            - threads are not being managed properly
#                            - checking network activity- pegging thru the roof
#                            - listening ports
#                    - Windows 10
#                        - Microsoft Edge and Cortana are taking up all resources
#                        - Microsoft Edge - used most resources
#                        - tasklist | more
#
#            - Task Manager Demo
#                - Tasklist
#                - taskkill /f /pid 1111
#                - Taskkill /f /IM svchost.exe
#
#
#            - Context Menu:
#                - open file location
#                - end process
#                - end process tree
#                - UAC Virtualization
#                - Create Dump FIle
#                - Set Priority
#                - Set Affinity
#                - Go To Services (services.msc)
#                    - Can start any service from net start
#                    - Can stop any service from net stop
#                - Performance Tab
#                    - Multiple CPUs/Cores
#
#
#           - Activity: Download Free Process Explorer tool for greater
#
#           - Performance Monitor
#
#               - Perfmon.msc
#               - Toogle checkbox to see descriptions of Add Counter
#                   - perfmon /report
#                   - logman export the report to xml file
#
#               -Export Data Collector Set with logman
#                   - logman export -n "TCP_Data" -xm "C:\Users\IEUser\TCP_Data_Template.xml"
#
#
#            - Brief discussion of COM objects and ODBC
#
#           - Activit:  Have students build out their WIndows Registry Security
#
#           - Ways to diagnose
#               - cpu usage
#               - checkout network activity
#               - perf monitor
#               - perf manager
#
#
#               Registry - how registry can be exploited and protected
#
#               - Read up to Chapter 13
#               - Read all the Operating Stufffs
#
#
#               Weekly deliverables
#               - Build windows registry
#               - Research
#               - Compile Malware
#               - Standard windows services
#               - How to find malware on your computer
#               https://peter.hanhndorf.eu/tech/malware.html
#               - Activity:  Create a SystInternals malware monitoring implementaiton guide
#               - Activity:  Create a custom Data Collector Set and export to be copied across to other systems
#               - Activity:  Setup critical system monitoring in Performance Monitor
#               - Activity: Have students build out their Windows Registry Security playbook for common exploits and how to clean at both user and enterprise level
#               - Activity: Research how viruses target the bootmgr and how to protect it
#               - Activity: Start to compile Malware Analysis guide using Task Manager
#                   - What are the standard WIndows services running on a new system
#                   - How do you account for hidden processes?
#                   - What are some common troubleshooting tools you can use
#                       https://peter.hahndorf.eu/tech/malware.html
#
#                   - how to disable task manager
#
#                   Windows Registry Editor Version 5.00
#                   [HKEY_CURRENT_USER\Software\Microsoft\Windows\CurrentVersion\Policies\System] "DisableTasMgr"=dword:0000000
#
#
#     - catalog resource
#         - google-fu
#
# ### Day 3 - Saturday - 9 hours
#     - User and Group Management in Windows
#     - Command line net localgroup and net users
#     - Group Policy Editor
#
#
#
# ### Resources
